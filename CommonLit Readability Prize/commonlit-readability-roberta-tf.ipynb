# %% [markdown]
# https://uku28motab.feishu.cn/docs/doccnUDbEhudHm2V440lcY87B1c

# %%
# 导入相关的库
import re
import os
import numpy as np
import pandas as pd
import random
import math
import tensorflow as tf
import logging
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from tensorflow.keras import backend as K
from transformers import RobertaTokenizer, TFRobertaModel
from kaggle_datasets import KaggleDatasets
tf.get_logger().setLevel(logging.ERROR)
from kaggle_datasets import KaggleDatasets

# %%
# 配置
EPOCHS = 70
# Batch size
BATCH_SIZE = 24
# 随机种子
SEED = 123
# Learning rate
LR = 0.000040
# Verbosity
VERBOSE = 2
# 交叉验证折数
FOLDS = 5

# 最大长度
MAX_LEN = 250

# 获取想使用的预训练模型
MODEL = 'roberta-base'

# 读取预训练模型的分词
tokenizer = RobertaTokenizer.from_pretrained(MODEL)

# tensorflow数据集
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# 随机种子
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# 这个函数根据转换器模型标记器对文本进行标记
def regular_encode(texts, tokenizer, maxlen = MAX_LEN):
    enc_di = tokenizer.batch_encode_plus(
        texts,
        padding = 'max_length',
        truncation = True,
        max_length = maxlen,
    )
    
    return np.array(enc_di['input_ids'])

# 这个函数对我们的训练句子进行编码
def encode_texts(x_train, x_val, MAX_LEN):
    x_train = regular_encode(x_train.tolist(), tokenizer, maxlen = MAX_LEN)
    x_val = regular_encode(x_val.tolist(), tokenizer, maxlen = MAX_LEN)
    return x_train, x_val

# 函数将数组转换为张量
def transform_to_tensors(x_train, x_val, y_train, y_val):
    
    train_dataset = (
        tf.data.Dataset
        .from_tensor_slices((x_train, y_train))
        .repeat()
        .shuffle(2048)
        .batch(BATCH_SIZE)
        .prefetch(AUTO)
    )
    
    valid_dataset = (
        tf.data.Dataset
        .from_tensor_slices((x_val, y_val))
        .batch(BATCH_SIZE)
        .prefetch(AUTO)
    )
    
    return train_dataset, valid_dataset

# 构建roberta_base模型
def build_roberta_base_model(max_len = MAX_LEN):
    transformer = TFRobertaModel.from_pretrained(MODEL)
    input_word_ids = tf.keras.layers.Input(shape = (max_len, ), dtype = tf.int32, name = 'input_word_ids')
    sequence_output = transformer(input_word_ids)[0]
    # We only need the cls_token, resulting in a 2d array
    cls_token = sequence_output[:, 0, :]
    output = tf.keras.layers.Dense(1, activation = 'linear', dtype = 'float32')(cls_token)
    model = tf.keras.models.Model(inputs = [input_word_ids], outputs = [output])
    model.compile(optimizer = tf.keras.optimizers.Adam(lr = LR),
                  loss = [tf.keras.losses.MeanSquaredError()],
                  metrics = [tf.keras.metrics.RootMeanSquaredError()])
    return model

# 训练和验证函数
def train_and_evaluate():
    
    # 读取训练数据
    df = pd.read_csv('../input/commonlitreadabilityprize/train.csv')
    # 随机种子
    seed_everything(SEED)
    
    # 使用shuffle和特定的seed启动kfold对象
    kfold = KFold(n_splits = FOLDS, shuffle = True, random_state = SEED)
    # 创建出折叠数组来存储预测
    oof_predictions = np.zeros(len(df))
    
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(df)):
        print('\n')
        print('-'*50)
        print(f'Training fold {fold + 1}')
        K.clear_session()
        # 获取文本特征和目标
        x_train, x_val = df['excerpt'].iloc[trn_ind], df['excerpt'].iloc[val_ind]
        y_train, y_val = df['target'].iloc[trn_ind].values, df['target'].iloc[val_ind].values
        # ERoberta 分词器编码文本
        x_train, x_val = encode_texts(x_train, x_val, MAX_LEN)
        # 函数将numpy数组转换为tf数据集
        train_dataset, valid_dataset = transform_to_tensors(x_train, x_val, y_train, y_val)
        # 构建模型
        model = build_roberta_base_model(max_len = MAX_LEN)
        # 模型保存
        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Roberta_Base_{SEED}_{fold + 1}.h5', 
                                                        monitor = 'val_root_mean_squared_error', 
                                                        verbose = VERBOSE, 
                                                        save_best_only = True,
                                                        save_weights_only = True, 
                                                        mode = 'min')
        steps = x_train.shape[0] // (BATCH_SIZE * 16)
        # 训练阶段
        history = model.fit(train_dataset,
                            batch_size = BATCH_SIZE,
                            epochs = EPOCHS,
                            verbose = VERBOSE,
                            callbacks = [checkpoint],
                            validation_data = valid_dataset,
                            steps_per_epoch = steps)
        
        
        # 读取最佳周期权重
        model.load_weights(f'Roberta_Base_{SEED}_{fold + 1}.h5')
        # Predict validation set to save them in the out of folds array
        val_pred = model.predict(valid_dataset)
        oof_predictions[val_ind] = val_pred.reshape(-1)
        
    print('\n')
    print('-'*50)
    # 预测验证集，将它们保存在数组中
    oof_rmse = np.sqrt(mean_squared_error(df['target'], oof_predictions))
    print(f'Our out of folds RMSE is {oof_rmse}')
    
# 执行训练和验证函数
train_and_evaluate()
# Out:
# --------------------------------------------------
# Training fold 1
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/657M [00:00<?, ?B/s]
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/70
# 5/5 - 27s - loss: 1.0869 - root_mean_squared_error: 1.0425 - val_loss: 1.0498 - val_root_mean_squared_error: 1.0246
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.02460, saving model to Roberta_Base_123_1.h5
# Epoch 2/70
# 5/5 - 9s - loss: 1.1106 - root_mean_squared_error: 1.0538 - val_loss: 1.0096 - val_root_mean_squared_error: 1.0048
#
# Epoch 00002: val_root_mean_squared_error improved from 1.02460 to 1.00477, saving model to Roberta_Base_123_1.h5
# Epoch 3/70
# 5/5 - 9s - loss: 1.1947 - root_mean_squared_error: 1.0930 - val_loss: 0.6229 - val_root_mean_squared_error: 0.7892
#
# Epoch 00003: val_root_mean_squared_error improved from 1.00477 to 0.78922, saving model to Roberta_Base_123_1.h5
# Epoch 4/70
# 5/5 - 9s - loss: 0.6912 - root_mean_squared_error: 0.8314 - val_loss: 0.4915 - val_root_mean_squared_error: 0.7011
#
# Epoch 00004: val_root_mean_squared_error improved from 0.78922 to 0.70105, saving model to Roberta_Base_123_1.h5
# Epoch 5/70
# 5/5 - 9s - loss: 0.9747 - root_mean_squared_error: 0.9873 - val_loss: 1.1234 - val_root_mean_squared_error: 1.0599
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.70105
# Epoch 6/70
# 5/5 - 9s - loss: 0.7892 - root_mean_squared_error: 0.8883 - val_loss: 0.5976 - val_root_mean_squared_error: 0.7730
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.70105
# Epoch 7/70
# 5/5 - 9s - loss: 0.7129 - root_mean_squared_error: 0.8443 - val_loss: 0.7388 - val_root_mean_squared_error: 0.8596
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.70105
# Epoch 8/70
# 5/5 - 9s - loss: 0.6328 - root_mean_squared_error: 0.7955 - val_loss: 0.4691 - val_root_mean_squared_error: 0.6849
#
# Epoch 00008: val_root_mean_squared_error improved from 0.70105 to 0.68494, saving model to Roberta_Base_123_1.h5
# Epoch 9/70
# 5/5 - 9s - loss: 0.4095 - root_mean_squared_error: 0.6399 - val_loss: 0.8066 - val_root_mean_squared_error: 0.8981
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.68494
# Epoch 10/70
# 5/5 - 9s - loss: 0.5514 - root_mean_squared_error: 0.7426 - val_loss: 0.4315 - val_root_mean_squared_error: 0.6569
#
# Epoch 00010: val_root_mean_squared_error improved from 0.68494 to 0.65690, saving model to Roberta_Base_123_1.h5
# Epoch 11/70
# 5/5 - 9s - loss: 0.5638 - root_mean_squared_error: 0.7509 - val_loss: 0.6409 - val_root_mean_squared_error: 0.8006
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.65690
# Epoch 12/70
# 5/5 - 9s - loss: 0.5189 - root_mean_squared_error: 0.7203 - val_loss: 0.3789 - val_root_mean_squared_error: 0.6155
#
# Epoch 00012: val_root_mean_squared_error improved from 0.65690 to 0.61551, saving model to Roberta_Base_123_1.h5
# Epoch 13/70
# 5/5 - 9s - loss: 0.4605 - root_mean_squared_error: 0.6786 - val_loss: 0.6148 - val_root_mean_squared_error: 0.7841
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.61551
# Epoch 14/70
# 5/5 - 9s - loss: 0.5295 - root_mean_squared_error: 0.7276 - val_loss: 0.3591 - val_root_mean_squared_error: 0.5992
#
# Epoch 00014: val_root_mean_squared_error improved from 0.61551 to 0.59922, saving model to Roberta_Base_123_1.h5
# Epoch 15/70
# 5/5 - 9s - loss: 0.4637 - root_mean_squared_error: 0.6810 - val_loss: 0.7203 - val_root_mean_squared_error: 0.8487
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.59922
# Epoch 16/70
# 5/5 - 9s - loss: 0.3945 - root_mean_squared_error: 0.6281 - val_loss: 0.3704 - val_root_mean_squared_error: 0.6086
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.59922
# Epoch 17/70
# 5/5 - 9s - loss: 0.4036 - root_mean_squared_error: 0.6353 - val_loss: 0.6897 - val_root_mean_squared_error: 0.8305
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.59922
# Epoch 18/70
# 5/5 - 9s - loss: 0.4112 - root_mean_squared_error: 0.6413 - val_loss: 0.3281 - val_root_mean_squared_error: 0.5728
#
# Epoch 00018: val_root_mean_squared_error improved from 0.59922 to 0.57282, saving model to Roberta_Base_123_1.h5
# Epoch 19/70
# 5/5 - 9s - loss: 0.3864 - root_mean_squared_error: 0.6216 - val_loss: 0.3262 - val_root_mean_squared_error: 0.5712
#
# Epoch 00019: val_root_mean_squared_error improved from 0.57282 to 0.57116, saving model to Roberta_Base_123_1.h5
# Epoch 20/70
# 5/5 - 9s - loss: 0.4538 - root_mean_squared_error: 0.6736 - val_loss: 0.8636 - val_root_mean_squared_error: 0.9293
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.57116
# Epoch 21/70
# 5/5 - 9s - loss: 0.4852 - root_mean_squared_error: 0.6966 - val_loss: 0.3055 - val_root_mean_squared_error: 0.5527
#
# Epoch 00021: val_root_mean_squared_error improved from 0.57116 to 0.55272, saving model to Roberta_Base_123_1.h5
# Epoch 22/70
# 5/5 - 9s - loss: 0.3358 - root_mean_squared_error: 0.5794 - val_loss: 0.5965 - val_root_mean_squared_error: 0.7723
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.55272
# Epoch 23/70
# 5/5 - 9s - loss: 0.4015 - root_mean_squared_error: 0.6336 - val_loss: 0.3063 - val_root_mean_squared_error: 0.5535
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.55272
# Epoch 24/70
# 5/5 - 9s - loss: 0.3022 - root_mean_squared_error: 0.5497 - val_loss: 0.4773 - val_root_mean_squared_error: 0.6909
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.55272
# Epoch 25/70
# 5/5 - 9s - loss: 0.2687 - root_mean_squared_error: 0.5184 - val_loss: 0.3642 - val_root_mean_squared_error: 0.6035
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.55272
# Epoch 26/70
# 5/5 - 9s - loss: 0.3105 - root_mean_squared_error: 0.5573 - val_loss: 0.4530 - val_root_mean_squared_error: 0.6730
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.55272
# Epoch 27/70
# 5/5 - 9s - loss: 0.2651 - root_mean_squared_error: 0.5149 - val_loss: 0.2838 - val_root_mean_squared_error: 0.5328
#
# Epoch 00027: val_root_mean_squared_error improved from 0.55272 to 0.53277, saving model to Roberta_Base_123_1.h5
# Epoch 28/70
# 5/5 - 9s - loss: 0.3510 - root_mean_squared_error: 0.5924 - val_loss: 0.3810 - val_root_mean_squared_error: 0.6172
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.53277
# Epoch 29/70
# 5/5 - 9s - loss: 0.3568 - root_mean_squared_error: 0.5974 - val_loss: 0.4328 - val_root_mean_squared_error: 0.6578
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.53277
# Epoch 30/70
# 5/5 - 9s - loss: 0.2692 - root_mean_squared_error: 0.5188 - val_loss: 0.4330 - val_root_mean_squared_error: 0.6581
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.53277
# Epoch 31/70
# 5/5 - 9s - loss: 0.2400 - root_mean_squared_error: 0.4899 - val_loss: 0.3642 - val_root_mean_squared_error: 0.6035
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.53277
# Epoch 32/70
# 5/5 - 9s - loss: 0.2443 - root_mean_squared_error: 0.4943 - val_loss: 0.3040 - val_root_mean_squared_error: 0.5513
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.53277
# Epoch 33/70
# 5/5 - 9s - loss: 0.2733 - root_mean_squared_error: 0.5228 - val_loss: 0.3594 - val_root_mean_squared_error: 0.5995
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.53277
# Epoch 34/70
# 5/5 - 9s - loss: 0.3328 - root_mean_squared_error: 0.5769 - val_loss: 0.2744 - val_root_mean_squared_error: 0.5239
#
# Epoch 00034: val_root_mean_squared_error improved from 0.53277 to 0.52387, saving model to Roberta_Base_123_1.h5
# Epoch 35/70
# 5/5 - 9s - loss: 0.2793 - root_mean_squared_error: 0.5284 - val_loss: 0.5553 - val_root_mean_squared_error: 0.7452
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.52387
# Epoch 36/70
# 5/5 - 9s - loss: 0.2477 - root_mean_squared_error: 0.4977 - val_loss: 0.3471 - val_root_mean_squared_error: 0.5892
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.52387
# Epoch 37/70
# 5/5 - 9s - loss: 0.2413 - root_mean_squared_error: 0.4913 - val_loss: 0.2772 - val_root_mean_squared_error: 0.5265
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.52387
# Epoch 38/70
# 5/5 - 9s - loss: 0.3143 - root_mean_squared_error: 0.5607 - val_loss: 0.7496 - val_root_mean_squared_error: 0.8658
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.52387
# Epoch 39/70
# 5/5 - 9s - loss: 0.3812 - root_mean_squared_error: 0.6174 - val_loss: 0.2805 - val_root_mean_squared_error: 0.5296
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.52387
# Epoch 40/70
# 5/5 - 9s - loss: 0.2551 - root_mean_squared_error: 0.5051 - val_loss: 0.4127 - val_root_mean_squared_error: 0.6424
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.52387
# Epoch 41/70
# 5/5 - 9s - loss: 0.2899 - root_mean_squared_error: 0.5385 - val_loss: 0.3448 - val_root_mean_squared_error: 0.5872
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.52387
# Epoch 42/70
# 5/5 - 9s - loss: 0.1968 - root_mean_squared_error: 0.4436 - val_loss: 0.3230 - val_root_mean_squared_error: 0.5683
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.52387
# Epoch 43/70
# 5/5 - 9s - loss: 0.2393 - root_mean_squared_error: 0.4892 - val_loss: 0.3621 - val_root_mean_squared_error: 0.6018
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.52387
# Epoch 44/70
# 5/5 - 9s - loss: 0.2559 - root_mean_squared_error: 0.5059 - val_loss: 0.3046 - val_root_mean_squared_error: 0.5519
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.52387
# Epoch 45/70
# 5/5 - 9s - loss: 0.2239 - root_mean_squared_error: 0.4732 - val_loss: 0.6010 - val_root_mean_squared_error: 0.7752
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.52387
# Epoch 46/70
# 5/5 - 9s - loss: 0.3010 - root_mean_squared_error: 0.5487 - val_loss: 0.4329 - val_root_mean_squared_error: 0.6579
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.52387
# Epoch 47/70
# 5/5 - 9s - loss: 0.1858 - root_mean_squared_error: 0.4310 - val_loss: 0.3551 - val_root_mean_squared_error: 0.5959
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.52387
# Epoch 48/70
# 5/5 - 9s - loss: 0.1771 - root_mean_squared_error: 0.4209 - val_loss: 0.4721 - val_root_mean_squared_error: 0.6871
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.52387
# Epoch 49/70
# 5/5 - 9s - loss: 0.1976 - root_mean_squared_error: 0.4445 - val_loss: 0.2947 - val_root_mean_squared_error: 0.5429
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.52387
# Epoch 50/70
# 5/5 - 9s - loss: 0.2074 - root_mean_squared_error: 0.4555 - val_loss: 0.4093 - val_root_mean_squared_error: 0.6398
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.52387
# Epoch 51/70
# 5/5 - 9s - loss: 0.1892 - root_mean_squared_error: 0.4349 - val_loss: 0.5939 - val_root_mean_squared_error: 0.7707
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.52387
# Epoch 52/70
# 5/5 - 9s - loss: 0.1303 - root_mean_squared_error: 0.3610 - val_loss: 0.4211 - val_root_mean_squared_error: 0.6489
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.52387
# Epoch 53/70
# 5/5 - 9s - loss: 0.1794 - root_mean_squared_error: 0.4236 - val_loss: 0.3637 - val_root_mean_squared_error: 0.6031
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.52387
# Epoch 54/70
# 5/5 - 9s - loss: 0.1632 - root_mean_squared_error: 0.4040 - val_loss: 0.3921 - val_root_mean_squared_error: 0.6262
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.52387
# Epoch 55/70
# 5/5 - 9s - loss: 0.1553 - root_mean_squared_error: 0.3940 - val_loss: 0.2876 - val_root_mean_squared_error: 0.5363
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.52387
# Epoch 56/70
# 5/5 - 9s - loss: 0.1767 - root_mean_squared_error: 0.4204 - val_loss: 0.5086 - val_root_mean_squared_error: 0.7131
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.52387
# Epoch 57/70
# 5/5 - 9s - loss: 0.1736 - root_mean_squared_error: 0.4166 - val_loss: 0.5278 - val_root_mean_squared_error: 0.7265
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.52387
# Epoch 58/70
# 5/5 - 9s - loss: 0.2028 - root_mean_squared_error: 0.4504 - val_loss: 0.2952 - val_root_mean_squared_error: 0.5433
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.52387
# Epoch 59/70
# 5/5 - 9s - loss: 0.1840 - root_mean_squared_error: 0.4290 - val_loss: 0.4917 - val_root_mean_squared_error: 0.7012
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.52387
# Epoch 60/70
# 5/5 - 9s - loss: 0.1467 - root_mean_squared_error: 0.3830 - val_loss: 0.5142 - val_root_mean_squared_error: 0.7171
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.52387
# Epoch 61/70
# 5/5 - 9s - loss: 0.1089 - root_mean_squared_error: 0.3300 - val_loss: 0.2873 - val_root_mean_squared_error: 0.5360
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.52387
# Epoch 62/70
# 5/5 - 9s - loss: 0.1544 - root_mean_squared_error: 0.3930 - val_loss: 0.4665 - val_root_mean_squared_error: 0.6830
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.52387
# Epoch 63/70
# 5/5 - 9s - loss: 0.1508 - root_mean_squared_error: 0.3884 - val_loss: 0.3933 - val_root_mean_squared_error: 0.6271
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.52387
# Epoch 64/70
# 5/5 - 9s - loss: 0.1624 - root_mean_squared_error: 0.4030 - val_loss: 0.3744 - val_root_mean_squared_error: 0.6118
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.52387
# Epoch 65/70
# 5/5 - 9s - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.3972 - val_root_mean_squared_error: 0.6303
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.52387
# Epoch 66/70
# 5/5 - 9s - loss: 0.1468 - root_mean_squared_error: 0.3831 - val_loss: 0.5811 - val_root_mean_squared_error: 0.7623
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.52387
# Epoch 67/70
# 5/5 - 9s - loss: 0.1824 - root_mean_squared_error: 0.4271 - val_loss: 0.3600 - val_root_mean_squared_error: 0.6000
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.52387
# Epoch 68/70
# 5/5 - 9s - loss: 0.1306 - root_mean_squared_error: 0.3614 - val_loss: 0.4595 - val_root_mean_squared_error: 0.6779
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.52387
# Epoch 69/70
# 5/5 - 9s - loss: 0.1347 - root_mean_squared_error: 0.3670 - val_loss: 0.3691 - val_root_mean_squared_error: 0.6075
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.52387
# Epoch 70/70
# 5/5 - 9s - loss: 0.1596 - root_mean_squared_error: 0.3995 - val_loss: 0.4846 - val_root_mean_squared_error: 0.6962
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.52387
#
#
# --------------------------------------------------
# Training fold 2
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/70
# 5/5 - 26s - loss: 1.3435 - root_mean_squared_error: 1.1591 - val_loss: 1.1107 - val_root_mean_squared_error: 1.0539
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.05388, saving model to Roberta_Base_123_2.h5
# Epoch 2/70
# 5/5 - 9s - loss: 0.9537 - root_mean_squared_error: 0.9766 - val_loss: 0.8807 - val_root_mean_squared_error: 0.9385
#
# Epoch 00002: val_root_mean_squared_error improved from 1.05388 to 0.93848, saving model to Roberta_Base_123_2.h5
# Epoch 3/70
# 5/5 - 9s - loss: 0.8168 - root_mean_squared_error: 0.9038 - val_loss: 1.0929 - val_root_mean_squared_error: 1.0454
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.93848
# Epoch 4/70
# 5/5 - 9s - loss: 0.7448 - root_mean_squared_error: 0.8630 - val_loss: 0.6829 - val_root_mean_squared_error: 0.8264
#
# Epoch 00004: val_root_mean_squared_error improved from 0.93848 to 0.82637, saving model to Roberta_Base_123_2.h5
# Epoch 5/70
# 5/5 - 9s - loss: 0.9309 - root_mean_squared_error: 0.9648 - val_loss: 0.9794 - val_root_mean_squared_error: 0.9896
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.82637
# Epoch 6/70
# 5/5 - 9s - loss: 0.7246 - root_mean_squared_error: 0.8513 - val_loss: 0.4343 - val_root_mean_squared_error: 0.6590
#
# Epoch 00006: val_root_mean_squared_error improved from 0.82637 to 0.65901, saving model to Roberta_Base_123_2.h5
# Epoch 7/70
# 5/5 - 9s - loss: 0.4876 - root_mean_squared_error: 0.6983 - val_loss: 0.6662 - val_root_mean_squared_error: 0.8162
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.65901
# Epoch 8/70
# 5/5 - 9s - loss: 0.4625 - root_mean_squared_error: 0.6801 - val_loss: 0.4478 - val_root_mean_squared_error: 0.6692
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.65901
# Epoch 9/70
# 5/5 - 9s - loss: 0.4921 - root_mean_squared_error: 0.7015 - val_loss: 0.5613 - val_root_mean_squared_error: 0.7492
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.65901
# Epoch 10/70
# 5/5 - 9s - loss: 0.3883 - root_mean_squared_error: 0.6231 - val_loss: 0.4118 - val_root_mean_squared_error: 0.6417
#
# Epoch 00010: val_root_mean_squared_error improved from 0.65901 to 0.64173, saving model to Roberta_Base_123_2.h5
# Epoch 11/70
# 5/5 - 9s - loss: 0.3476 - root_mean_squared_error: 0.5895 - val_loss: 0.4231 - val_root_mean_squared_error: 0.6505
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.64173
# Epoch 12/70
# 5/5 - 9s - loss: 0.2716 - root_mean_squared_error: 0.5211 - val_loss: 0.4989 - val_root_mean_squared_error: 0.7064
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.64173
# Epoch 13/70
# 5/5 - 9s - loss: 0.3493 - root_mean_squared_error: 0.5910 - val_loss: 0.5311 - val_root_mean_squared_error: 0.7287
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.64173
# Epoch 14/70
# 5/5 - 9s - loss: 0.3099 - root_mean_squared_error: 0.5567 - val_loss: 0.3114 - val_root_mean_squared_error: 0.5581
#
# Epoch 00014: val_root_mean_squared_error improved from 0.64173 to 0.55806, saving model to Roberta_Base_123_2.h5
# Epoch 15/70
# 5/5 - 9s - loss: 0.4548 - root_mean_squared_error: 0.6744 - val_loss: 0.3397 - val_root_mean_squared_error: 0.5828
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.55806
# Epoch 16/70
# 5/5 - 9s - loss: 0.4361 - root_mean_squared_error: 0.6603 - val_loss: 0.7166 - val_root_mean_squared_error: 0.8465
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.55806
# Epoch 17/70
# 5/5 - 9s - loss: 0.4321 - root_mean_squared_error: 0.6574 - val_loss: 0.3153 - val_root_mean_squared_error: 0.5615
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.55806
# Epoch 18/70
# 5/5 - 9s - loss: 0.4870 - root_mean_squared_error: 0.6978 - val_loss: 0.3206 - val_root_mean_squared_error: 0.5662
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.55806
# Epoch 19/70
# 5/5 - 9s - loss: 0.4477 - root_mean_squared_error: 0.6691 - val_loss: 0.6136 - val_root_mean_squared_error: 0.7833
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.55806
# Epoch 20/70
# 5/5 - 9s - loss: 0.4625 - root_mean_squared_error: 0.6801 - val_loss: 0.3264 - val_root_mean_squared_error: 0.5713
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.55806
# Epoch 21/70
# 5/5 - 9s - loss: 0.2600 - root_mean_squared_error: 0.5099 - val_loss: 0.4071 - val_root_mean_squared_error: 0.6380
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.55806
# Epoch 22/70
# 5/5 - 9s - loss: 0.2616 - root_mean_squared_error: 0.5115 - val_loss: 0.3775 - val_root_mean_squared_error: 0.6144
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.55806
# Epoch 23/70
# 5/5 - 9s - loss: 0.2693 - root_mean_squared_error: 0.5189 - val_loss: 0.4127 - val_root_mean_squared_error: 0.6424
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.55806
# Epoch 24/70
# 5/5 - 9s - loss: 0.2873 - root_mean_squared_error: 0.5360 - val_loss: 0.4878 - val_root_mean_squared_error: 0.6984
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.55806
# Epoch 25/70
# 5/5 - 9s - loss: 0.2755 - root_mean_squared_error: 0.5249 - val_loss: 0.3132 - val_root_mean_squared_error: 0.5597
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.55806
# Epoch 26/70
# 5/5 - 9s - loss: 0.2247 - root_mean_squared_error: 0.4740 - val_loss: 0.3233 - val_root_mean_squared_error: 0.5686
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.55806
# Epoch 27/70
# 5/5 - 9s - loss: 0.2282 - root_mean_squared_error: 0.4777 - val_loss: 0.3104 - val_root_mean_squared_error: 0.5572
#
# Epoch 00027: val_root_mean_squared_error improved from 0.55806 to 0.55717, saving model to Roberta_Base_123_2.h5
# Epoch 28/70
# 5/5 - 9s - loss: 0.2553 - root_mean_squared_error: 0.5052 - val_loss: 0.2954 - val_root_mean_squared_error: 0.5435
#
# Epoch 00028: val_root_mean_squared_error improved from 0.55717 to 0.54347, saving model to Roberta_Base_123_2.h5
# Epoch 29/70
# 5/5 - 9s - loss: 0.3497 - root_mean_squared_error: 0.5914 - val_loss: 0.3607 - val_root_mean_squared_error: 0.6006
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.54347
# Epoch 30/70
# 5/5 - 9s - loss: 0.2869 - root_mean_squared_error: 0.5357 - val_loss: 0.4805 - val_root_mean_squared_error: 0.6932
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.54347
# Epoch 31/70
# 5/5 - 9s - loss: 0.2515 - root_mean_squared_error: 0.5015 - val_loss: 0.3606 - val_root_mean_squared_error: 0.6005
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.54347
# Epoch 32/70
# 5/5 - 9s - loss: 0.1931 - root_mean_squared_error: 0.4394 - val_loss: 0.3944 - val_root_mean_squared_error: 0.6280
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.54347
# Epoch 33/70
# 5/5 - 9s - loss: 0.2186 - root_mean_squared_error: 0.4676 - val_loss: 0.3529 - val_root_mean_squared_error: 0.5941
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.54347
# Epoch 34/70
# 5/5 - 9s - loss: 0.2156 - root_mean_squared_error: 0.4643 - val_loss: 0.4793 - val_root_mean_squared_error: 0.6923
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.54347
# Epoch 35/70
# 5/5 - 9s - loss: 0.2646 - root_mean_squared_error: 0.5144 - val_loss: 0.3455 - val_root_mean_squared_error: 0.5878
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.54347
# Epoch 36/70
# 5/5 - 9s - loss: 0.1862 - root_mean_squared_error: 0.4315 - val_loss: 0.3935 - val_root_mean_squared_error: 0.6273
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.54347
# Epoch 37/70
# 5/5 - 9s - loss: 0.1982 - root_mean_squared_error: 0.4452 - val_loss: 0.6066 - val_root_mean_squared_error: 0.7788
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.54347
# Epoch 38/70
# 5/5 - 9s - loss: 0.2062 - root_mean_squared_error: 0.4541 - val_loss: 0.4130 - val_root_mean_squared_error: 0.6426
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.54347
# Epoch 39/70
# 5/5 - 9s - loss: 0.2201 - root_mean_squared_error: 0.4692 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5874
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.54347
# Epoch 40/70
# 5/5 - 9s - loss: 0.1382 - root_mean_squared_error: 0.3717 - val_loss: 0.2913 - val_root_mean_squared_error: 0.5397
#
# Epoch 00040: val_root_mean_squared_error improved from 0.54347 to 0.53969, saving model to Roberta_Base_123_2.h5
# Epoch 41/70
# 5/5 - 9s - loss: 0.1835 - root_mean_squared_error: 0.4283 - val_loss: 0.5206 - val_root_mean_squared_error: 0.7215
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.53969
# Epoch 42/70
# 5/5 - 9s - loss: 0.1598 - root_mean_squared_error: 0.3998 - val_loss: 0.3479 - val_root_mean_squared_error: 0.5898
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.53969
# Epoch 43/70
# 5/5 - 9s - loss: 0.2122 - root_mean_squared_error: 0.4607 - val_loss: 0.3072 - val_root_mean_squared_error: 0.5543
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.53969
# Epoch 44/70
# 5/5 - 9s - loss: 0.1824 - root_mean_squared_error: 0.4270 - val_loss: 0.3188 - val_root_mean_squared_error: 0.5646
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.53969
# Epoch 45/70
# 5/5 - 9s - loss: 0.2306 - root_mean_squared_error: 0.4802 - val_loss: 0.4379 - val_root_mean_squared_error: 0.6617
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.53969
# Epoch 46/70
# 5/5 - 9s - loss: 0.2385 - root_mean_squared_error: 0.4883 - val_loss: 0.3262 - val_root_mean_squared_error: 0.5712
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.53969
# Epoch 47/70
# 5/5 - 9s - loss: 0.2300 - root_mean_squared_error: 0.4796 - val_loss: 0.5215 - val_root_mean_squared_error: 0.7221
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.53969
# Epoch 48/70
# 5/5 - 9s - loss: 0.1820 - root_mean_squared_error: 0.4266 - val_loss: 0.9331 - val_root_mean_squared_error: 0.9660
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.53969
# Epoch 49/70
# 5/5 - 9s - loss: 0.2928 - root_mean_squared_error: 0.5411 - val_loss: 0.3250 - val_root_mean_squared_error: 0.5701
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.53969
# Epoch 50/70
# 5/5 - 9s - loss: 0.2368 - root_mean_squared_error: 0.4867 - val_loss: 0.2965 - val_root_mean_squared_error: 0.5445
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.53969
# Epoch 51/70
# 5/5 - 9s - loss: 0.2679 - root_mean_squared_error: 0.5176 - val_loss: 0.4004 - val_root_mean_squared_error: 0.6327
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.53969
# Epoch 52/70
# 5/5 - 9s - loss: 0.1695 - root_mean_squared_error: 0.4117 - val_loss: 0.4045 - val_root_mean_squared_error: 0.6360
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.53969
# Epoch 53/70
# 5/5 - 9s - loss: 0.1809 - root_mean_squared_error: 0.4253 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5797
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.53969
# Epoch 54/70
# 5/5 - 9s - loss: 0.1257 - root_mean_squared_error: 0.3545 - val_loss: 0.3728 - val_root_mean_squared_error: 0.6106
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.53969
# Epoch 55/70
# 5/5 - 9s - loss: 0.1290 - root_mean_squared_error: 0.3592 - val_loss: 0.5920 - val_root_mean_squared_error: 0.7694
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.53969
# Epoch 56/70
# 5/5 - 9s - loss: 0.2078 - root_mean_squared_error: 0.4558 - val_loss: 0.2510 - val_root_mean_squared_error: 0.5010
#
# Epoch 00056: val_root_mean_squared_error improved from 0.53969 to 0.50103, saving model to Roberta_Base_123_2.h5
# Epoch 57/70
# 5/5 - 9s - loss: 0.1655 - root_mean_squared_error: 0.4069 - val_loss: 0.3223 - val_root_mean_squared_error: 0.5677
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.50103
# Epoch 58/70
# 5/5 - 9s - loss: 0.1495 - root_mean_squared_error: 0.3866 - val_loss: 0.4424 - val_root_mean_squared_error: 0.6651
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.50103
# Epoch 59/70
# 5/5 - 9s - loss: 0.1664 - root_mean_squared_error: 0.4079 - val_loss: 0.3124 - val_root_mean_squared_error: 0.5589
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.50103
# Epoch 60/70
# 5/5 - 9s - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.3047 - val_root_mean_squared_error: 0.5520
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.50103
# Epoch 61/70
# 5/5 - 9s - loss: 0.1677 - root_mean_squared_error: 0.4095 - val_loss: 0.6184 - val_root_mean_squared_error: 0.7864
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.50103
# Epoch 62/70
# 5/5 - 9s - loss: 0.1776 - root_mean_squared_error: 0.4215 - val_loss: 0.5044 - val_root_mean_squared_error: 0.7102
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.50103
# Epoch 63/70
# 5/5 - 9s - loss: 0.1274 - root_mean_squared_error: 0.3569 - val_loss: 0.3241 - val_root_mean_squared_error: 0.5693
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.50103
# Epoch 64/70
# 5/5 - 9s - loss: 0.1418 - root_mean_squared_error: 0.3766 - val_loss: 0.4166 - val_root_mean_squared_error: 0.6454
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.50103
# Epoch 65/70
# 5/5 - 9s - loss: 0.1437 - root_mean_squared_error: 0.3791 - val_loss: 0.4018 - val_root_mean_squared_error: 0.6338
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.50103
# Epoch 66/70
# 5/5 - 9s - loss: 0.0996 - root_mean_squared_error: 0.3156 - val_loss: 0.4031 - val_root_mean_squared_error: 0.6349
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.50103
# Epoch 67/70
# 5/5 - 9s - loss: 0.1123 - root_mean_squared_error: 0.3352 - val_loss: 0.3609 - val_root_mean_squared_error: 0.6008
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.50103
# Epoch 68/70
# 5/5 - 9s - loss: 0.1178 - root_mean_squared_error: 0.3432 - val_loss: 0.4120 - val_root_mean_squared_error: 0.6419
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.50103
# Epoch 69/70
# 5/5 - 9s - loss: 0.1373 - root_mean_squared_error: 0.3706 - val_loss: 0.5162 - val_root_mean_squared_error: 0.7185
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.50103
# Epoch 70/70
# 5/5 - 9s - loss: 0.1549 - root_mean_squared_error: 0.3936 - val_loss: 0.3997 - val_root_mean_squared_error: 0.6322
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.50103
#
#
# --------------------------------------------------
# Training fold 3
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/70
# 5/5 - 27s - loss: 1.3198 - root_mean_squared_error: 1.1488 - val_loss: 1.0267 - val_root_mean_squared_error: 1.0133
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.01327, saving model to Roberta_Base_123_3.h5
# Epoch 2/70
# 5/5 - 9s - loss: 1.1690 - root_mean_squared_error: 1.0812 - val_loss: 0.9240 - val_root_mean_squared_error: 0.9613
#
# Epoch 00002: val_root_mean_squared_error improved from 1.01327 to 0.96127, saving model to Roberta_Base_123_3.h5
# Epoch 3/70
# 5/5 - 9s - loss: 1.0497 - root_mean_squared_error: 1.0246 - val_loss: 0.8003 - val_root_mean_squared_error: 0.8946
#
# Epoch 00003: val_root_mean_squared_error improved from 0.96127 to 0.89458, saving model to Roberta_Base_123_3.h5
# Epoch 4/70
# 5/5 - 9s - loss: 0.6972 - root_mean_squared_error: 0.8350 - val_loss: 0.5675 - val_root_mean_squared_error: 0.7533
#
# Epoch 00004: val_root_mean_squared_error improved from 0.89458 to 0.75332, saving model to Roberta_Base_123_3.h5
# Epoch 5/70
# 5/5 - 9s - loss: 0.6441 - root_mean_squared_error: 0.8025 - val_loss: 0.4316 - val_root_mean_squared_error: 0.6570
#
# Epoch 00005: val_root_mean_squared_error improved from 0.75332 to 0.65696, saving model to Roberta_Base_123_3.h5
# Epoch 6/70
# 5/5 - 9s - loss: 0.4747 - root_mean_squared_error: 0.6890 - val_loss: 0.4265 - val_root_mean_squared_error: 0.6530
#
# Epoch 00006: val_root_mean_squared_error improved from 0.65696 to 0.65304, saving model to Roberta_Base_123_3.h5
# Epoch 7/70
# 5/5 - 9s - loss: 0.6153 - root_mean_squared_error: 0.7844 - val_loss: 0.4033 - val_root_mean_squared_error: 0.6351
#
# Epoch 00007: val_root_mean_squared_error improved from 0.65304 to 0.63509, saving model to Roberta_Base_123_3.h5
# Epoch 8/70
# 5/5 - 9s - loss: 0.4220 - root_mean_squared_error: 0.6496 - val_loss: 0.3953 - val_root_mean_squared_error: 0.6287
#
# Epoch 00008: val_root_mean_squared_error improved from 0.63509 to 0.62875, saving model to Roberta_Base_123_3.h5
# Epoch 9/70
# 5/5 - 9s - loss: 0.4408 - root_mean_squared_error: 0.6640 - val_loss: 0.4617 - val_root_mean_squared_error: 0.6795
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.62875
# Epoch 10/70
# 5/5 - 9s - loss: 0.3518 - root_mean_squared_error: 0.5931 - val_loss: 0.4535 - val_root_mean_squared_error: 0.6734
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.62875
# Epoch 11/70
# 5/5 - 9s - loss: 0.4686 - root_mean_squared_error: 0.6846 - val_loss: 0.3634 - val_root_mean_squared_error: 0.6028
#
# Epoch 00011: val_root_mean_squared_error improved from 0.62875 to 0.60279, saving model to Roberta_Base_123_3.h5
# Epoch 12/70
# 5/5 - 9s - loss: 0.3244 - root_mean_squared_error: 0.5696 - val_loss: 0.3678 - val_root_mean_squared_error: 0.6065
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.60279
# Epoch 13/70
# 5/5 - 9s - loss: 0.3914 - root_mean_squared_error: 0.6256 - val_loss: 0.3167 - val_root_mean_squared_error: 0.5628
#
# Epoch 00013: val_root_mean_squared_error improved from 0.60279 to 0.56278, saving model to Roberta_Base_123_3.h5
# Epoch 14/70
# 5/5 - 9s - loss: 0.4078 - root_mean_squared_error: 0.6386 - val_loss: 0.3027 - val_root_mean_squared_error: 0.5502
#
# Epoch 00014: val_root_mean_squared_error improved from 0.56278 to 0.55019, saving model to Roberta_Base_123_3.h5
# Epoch 15/70
# 5/5 - 9s - loss: 0.3689 - root_mean_squared_error: 0.6074 - val_loss: 0.4152 - val_root_mean_squared_error: 0.6444
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.55019
# Epoch 16/70
# 5/5 - 9s - loss: 0.3651 - root_mean_squared_error: 0.6042 - val_loss: 0.5294 - val_root_mean_squared_error: 0.7276
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.55019
# Epoch 17/70
# 5/5 - 9s - loss: 0.3477 - root_mean_squared_error: 0.5897 - val_loss: 0.3693 - val_root_mean_squared_error: 0.6077
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.55019
# Epoch 18/70
# 5/5 - 9s - loss: 0.3316 - root_mean_squared_error: 0.5759 - val_loss: 0.3696 - val_root_mean_squared_error: 0.6079
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.55019
# Epoch 19/70
# 5/5 - 9s - loss: 0.3141 - root_mean_squared_error: 0.5604 - val_loss: 0.3905 - val_root_mean_squared_error: 0.6249
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.55019
# Epoch 20/70
# 5/5 - 9s - loss: 0.3161 - root_mean_squared_error: 0.5622 - val_loss: 0.3024 - val_root_mean_squared_error: 0.5499
#
# Epoch 00020: val_root_mean_squared_error improved from 0.55019 to 0.54994, saving model to Roberta_Base_123_3.h5
# Epoch 21/70
# 5/5 - 9s - loss: 0.4778 - root_mean_squared_error: 0.6912 - val_loss: 0.3671 - val_root_mean_squared_error: 0.6059
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.54994
# Epoch 22/70
# 5/5 - 9s - loss: 0.2960 - root_mean_squared_error: 0.5441 - val_loss: 0.7181 - val_root_mean_squared_error: 0.8474
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.54994
# Epoch 23/70
# 5/5 - 9s - loss: 0.3030 - root_mean_squared_error: 0.5505 - val_loss: 0.3003 - val_root_mean_squared_error: 0.5480
#
# Epoch 00023: val_root_mean_squared_error improved from 0.54994 to 0.54795, saving model to Roberta_Base_123_3.h5
# Epoch 24/70
# 5/5 - 9s - loss: 0.3118 - root_mean_squared_error: 0.5584 - val_loss: 0.2984 - val_root_mean_squared_error: 0.5462
#
# Epoch 00024: val_root_mean_squared_error improved from 0.54795 to 0.54622, saving model to Roberta_Base_123_3.h5
# Epoch 25/70
# 5/5 - 9s - loss: 0.3258 - root_mean_squared_error: 0.5708 - val_loss: 0.3550 - val_root_mean_squared_error: 0.5958
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.54622
# Epoch 26/70
# 5/5 - 9s - loss: 0.2780 - root_mean_squared_error: 0.5272 - val_loss: 0.4865 - val_root_mean_squared_error: 0.6975
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.54622
# Epoch 27/70
# 5/5 - 9s - loss: 0.2418 - root_mean_squared_error: 0.4917 - val_loss: 0.3052 - val_root_mean_squared_error: 0.5524
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.54622
# Epoch 28/70
# 5/5 - 9s - loss: 0.2636 - root_mean_squared_error: 0.5135 - val_loss: 0.3216 - val_root_mean_squared_error: 0.5671
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.54622
# Epoch 29/70
# 5/5 - 9s - loss: 0.3495 - root_mean_squared_error: 0.5912 - val_loss: 0.5294 - val_root_mean_squared_error: 0.7276
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.54622
# Epoch 30/70
# 5/5 - 9s - loss: 0.2963 - root_mean_squared_error: 0.5443 - val_loss: 0.2951 - val_root_mean_squared_error: 0.5432
#
# Epoch 00030: val_root_mean_squared_error improved from 0.54622 to 0.54324, saving model to Roberta_Base_123_3.h5
# Epoch 31/70
# 5/5 - 9s - loss: 0.1917 - root_mean_squared_error: 0.4378 - val_loss: 0.3362 - val_root_mean_squared_error: 0.5799
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.54324
# Epoch 32/70
# 5/5 - 9s - loss: 0.1943 - root_mean_squared_error: 0.4408 - val_loss: 0.4473 - val_root_mean_squared_error: 0.6688
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.54324
# Epoch 33/70
# 5/5 - 9s - loss: 0.2167 - root_mean_squared_error: 0.4656 - val_loss: 0.3174 - val_root_mean_squared_error: 0.5634
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.54324
# Epoch 34/70
# 5/5 - 9s - loss: 0.1737 - root_mean_squared_error: 0.4167 - val_loss: 0.3023 - val_root_mean_squared_error: 0.5499
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.54324
# Epoch 35/70
# 5/5 - 9s - loss: 0.2526 - root_mean_squared_error: 0.5026 - val_loss: 0.3381 - val_root_mean_squared_error: 0.5814
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.54324
# Epoch 36/70
# 5/5 - 9s - loss: 0.2698 - root_mean_squared_error: 0.5194 - val_loss: 0.4805 - val_root_mean_squared_error: 0.6932
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.54324
# Epoch 37/70
# 5/5 - 9s - loss: 0.2193 - root_mean_squared_error: 0.4683 - val_loss: 0.4644 - val_root_mean_squared_error: 0.6815
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.54324
# Epoch 38/70
# 5/5 - 9s - loss: 0.1782 - root_mean_squared_error: 0.4221 - val_loss: 0.5937 - val_root_mean_squared_error: 0.7705
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.54324
# Epoch 39/70
# 5/5 - 9s - loss: 0.2750 - root_mean_squared_error: 0.5244 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5827
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.54324
# Epoch 40/70
# 5/5 - 9s - loss: 0.2374 - root_mean_squared_error: 0.4872 - val_loss: 0.2692 - val_root_mean_squared_error: 0.5188
#
# Epoch 00040: val_root_mean_squared_error improved from 0.54324 to 0.51884, saving model to Roberta_Base_123_3.h5
# Epoch 41/70
# 5/5 - 9s - loss: 0.1907 - root_mean_squared_error: 0.4367 - val_loss: 0.3338 - val_root_mean_squared_error: 0.5778
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.51884
# Epoch 42/70
# 5/5 - 9s - loss: 0.1989 - root_mean_squared_error: 0.4460 - val_loss: 0.5412 - val_root_mean_squared_error: 0.7357
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.51884
# Epoch 43/70
# 5/5 - 9s - loss: 0.2890 - root_mean_squared_error: 0.5376 - val_loss: 0.2720 - val_root_mean_squared_error: 0.5215
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.51884
# Epoch 44/70
# 5/5 - 9s - loss: 0.1925 - root_mean_squared_error: 0.4387 - val_loss: 0.2881 - val_root_mean_squared_error: 0.5368
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.51884
# Epoch 45/70
# 5/5 - 9s - loss: 0.2156 - root_mean_squared_error: 0.4643 - val_loss: 0.5145 - val_root_mean_squared_error: 0.7173
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.51884
# Epoch 46/70
# 5/5 - 9s - loss: 0.2246 - root_mean_squared_error: 0.4740 - val_loss: 0.4191 - val_root_mean_squared_error: 0.6474
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.51884
# Epoch 47/70
# 5/5 - 9s - loss: 0.2294 - root_mean_squared_error: 0.4789 - val_loss: 0.3016 - val_root_mean_squared_error: 0.5492
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.51884
# Epoch 48/70
# 5/5 - 9s - loss: 0.1605 - root_mean_squared_error: 0.4007 - val_loss: 0.3709 - val_root_mean_squared_error: 0.6090
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.51884
# Epoch 49/70
# 5/5 - 9s - loss: 0.1471 - root_mean_squared_error: 0.3836 - val_loss: 0.3901 - val_root_mean_squared_error: 0.6246
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.51884
# Epoch 50/70
# 5/5 - 9s - loss: 0.1408 - root_mean_squared_error: 0.3752 - val_loss: 0.4264 - val_root_mean_squared_error: 0.6530
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.51884
# Epoch 51/70
# 5/5 - 9s - loss: 0.1957 - root_mean_squared_error: 0.4424 - val_loss: 0.3863 - val_root_mean_squared_error: 0.6215
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.51884
# Epoch 52/70
# 5/5 - 9s - loss: 0.1893 - root_mean_squared_error: 0.4351 - val_loss: 0.4388 - val_root_mean_squared_error: 0.6624
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.51884
# Epoch 53/70
# 5/5 - 9s - loss: 0.1596 - root_mean_squared_error: 0.3995 - val_loss: 0.3433 - val_root_mean_squared_error: 0.5859
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.51884
# Epoch 54/70
# 5/5 - 9s - loss: 0.1591 - root_mean_squared_error: 0.3989 - val_loss: 0.3906 - val_root_mean_squared_error: 0.6250
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.51884
# Epoch 55/70
# 5/5 - 9s - loss: 0.1290 - root_mean_squared_error: 0.3592 - val_loss: 0.3946 - val_root_mean_squared_error: 0.6282
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.51884
# Epoch 56/70
# 5/5 - 9s - loss: 0.1578 - root_mean_squared_error: 0.3973 - val_loss: 0.2909 - val_root_mean_squared_error: 0.5394
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.51884
# Epoch 57/70
# 5/5 - 9s - loss: 0.1720 - root_mean_squared_error: 0.4147 - val_loss: 0.3441 - val_root_mean_squared_error: 0.5866
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.51884
# Epoch 58/70
# 5/5 - 9s - loss: 0.1882 - root_mean_squared_error: 0.4338 - val_loss: 0.5085 - val_root_mean_squared_error: 0.7131
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.51884
# Epoch 59/70
# 5/5 - 9s - loss: 0.1304 - root_mean_squared_error: 0.3611 - val_loss: 0.2838 - val_root_mean_squared_error: 0.5327
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.51884
# Epoch 60/70
# 5/5 - 9s - loss: 0.1935 - root_mean_squared_error: 0.4398 - val_loss: 0.5192 - val_root_mean_squared_error: 0.7205
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.51884
# Epoch 61/70
# 5/5 - 9s - loss: 0.1779 - root_mean_squared_error: 0.4218 - val_loss: 0.5420 - val_root_mean_squared_error: 0.7362
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.51884
# Epoch 62/70
# 5/5 - 9s - loss: 0.2011 - root_mean_squared_error: 0.4484 - val_loss: 0.6345 - val_root_mean_squared_error: 0.7965
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.51884
# Epoch 63/70
# 5/5 - 9s - loss: 0.2924 - root_mean_squared_error: 0.5408 - val_loss: 0.2931 - val_root_mean_squared_error: 0.5414
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.51884
# Epoch 64/70
# 5/5 - 9s - loss: 0.2255 - root_mean_squared_error: 0.4749 - val_loss: 0.3661 - val_root_mean_squared_error: 0.6051
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.51884
# Epoch 65/70
# 5/5 - 9s - loss: 0.1188 - root_mean_squared_error: 0.3447 - val_loss: 0.4481 - val_root_mean_squared_error: 0.6694
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.51884
# Epoch 66/70
# 5/5 - 9s - loss: 0.1431 - root_mean_squared_error: 0.3783 - val_loss: 0.2603 - val_root_mean_squared_error: 0.5102
#
# Epoch 00066: val_root_mean_squared_error improved from 0.51884 to 0.51022, saving model to Roberta_Base_123_3.h5
# Epoch 67/70
# 5/5 - 9s - loss: 0.1890 - root_mean_squared_error: 0.4348 - val_loss: 0.2813 - val_root_mean_squared_error: 0.5304
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.51022
# Epoch 68/70
# 5/5 - 9s - loss: 0.1188 - root_mean_squared_error: 0.3447 - val_loss: 0.5439 - val_root_mean_squared_error: 0.7375
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.51022
# Epoch 69/70
# 5/5 - 9s - loss: 0.2111 - root_mean_squared_error: 0.4595 - val_loss: 0.3331 - val_root_mean_squared_error: 0.5772
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.51022
# Epoch 70/70
# 5/5 - 9s - loss: 0.1725 - root_mean_squared_error: 0.4153 - val_loss: 0.2776 - val_root_mean_squared_error: 0.5269
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.51022
#
#
# --------------------------------------------------
# Training fold 4
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/70
# 5/5 - 27s - loss: 1.3500 - root_mean_squared_error: 1.1619 - val_loss: 1.5019 - val_root_mean_squared_error: 1.2255
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.22550, saving model to Roberta_Base_123_4.h5
# Epoch 2/70
# 5/5 - 9s - loss: 1.4675 - root_mean_squared_error: 1.2114 - val_loss: 0.9332 - val_root_mean_squared_error: 0.9660
#
# Epoch 00002: val_root_mean_squared_error improved from 1.22550 to 0.96601, saving model to Roberta_Base_123_4.h5
# Epoch 3/70
# 5/5 - 9s - loss: 1.2319 - root_mean_squared_error: 1.1099 - val_loss: 0.9981 - val_root_mean_squared_error: 0.9990
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.96601
# Epoch 4/70
# 5/5 - 9s - loss: 1.0294 - root_mean_squared_error: 1.0146 - val_loss: 1.0311 - val_root_mean_squared_error: 1.0154
#
# Epoch 00004: val_root_mean_squared_error did not improve from 0.96601
# Epoch 5/70
# 5/5 - 9s - loss: 0.9241 - root_mean_squared_error: 0.9613 - val_loss: 0.6042 - val_root_mean_squared_error: 0.7773
#
# ...
# Epoch 69/70
# 5/5 - 9s - loss: 0.1410 - root_mean_squared_error: 0.3755 - val_loss: 0.2953 - val_root_mean_squared_error: 0.5434
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.50104
# Epoch 70/70
# 5/5 - 9s - loss: 0.1450 - root_mean_squared_error: 0.3808 - val_loss: 0.6567 - val_root_mean_squared_error: 0.8104
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.50104
#
#
# --------------------------------------------------
# Training fold 5
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/70
# 5/5 - 27s - loss: 2.0511 - root_mean_squared_error: 1.4322 - val_loss: 0.9599 - val_root_mean_squared_error: 0.9798
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.97975, saving model to Roberta_Base_123_5.h5
# Epoch 2/70
# 5/5 - 9s - loss: 0.8735 - root_mean_squared_error: 0.9346 - val_loss: 0.9170 - val_root_mean_squared_error: 0.9576
#
# Epoch 00002: val_root_mean_squared_error improved from 0.97975 to 0.95760, saving model to Roberta_Base_123_5.h5
# Epoch 3/70
# 5/5 - 9s - loss: 1.0988 - root_mean_squared_error: 1.0482 - val_loss: 0.9492 - val_root_mean_squared_error: 0.9743
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.95760
# Epoch 4/70
# 5/5 - 9s - loss: 1.1854 - root_mean_squared_error: 1.0887 - val_loss: 0.8523 - val_root_mean_squared_error: 0.9232
#
# Epoch 00004: val_root_mean_squared_error improved from 0.95760 to 0.92320, saving model to Roberta_Base_123_5.h5
# Epoch 5/70
# 5/5 - 9s - loss: 0.8886 - root_mean_squared_error: 0.9426 - val_loss: 0.9653 - val_root_mean_squared_error: 0.9825
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.92320
# Epoch 6/70
# 5/5 - 9s - loss: 0.8238 - root_mean_squared_error: 0.9076 - val_loss: 0.5840 - val_root_mean_squared_error: 0.7642
#
# Epoch 00006: val_root_mean_squared_error improved from 0.92320 to 0.76421, saving model to Roberta_Base_123_5.h5
# Epoch 7/70
# 5/5 - 9s - loss: 0.4561 - root_mean_squared_error: 0.6754 - val_loss: 0.5247 - val_root_mean_squared_error: 0.7243
#
# Epoch 00007: val_root_mean_squared_error improved from 0.76421 to 0.72434, saving model to Roberta_Base_123_5.h5
# Epoch 8/70
# 5/5 - 9s - loss: 0.8145 - root_mean_squared_error: 0.9025 - val_loss: 0.5284 - val_root_mean_squared_error: 0.7269
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.72434
# Epoch 9/70
# 5/5 - 9s - loss: 0.7407 - root_mean_squared_error: 0.8606 - val_loss: 0.8157 - val_root_mean_squared_error: 0.9032
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.72434
# Epoch 10/70
# 5/5 - 9s - loss: 0.7241 - root_mean_squared_error: 0.8509 - val_loss: 0.4737 - val_root_mean_squared_error: 0.6883
#
# Epoch 00010: val_root_mean_squared_error improved from 0.72434 to 0.68826, saving model to Roberta_Base_123_5.h5
# Epoch 11/70
# 5/5 - 9s - loss: 0.7264 - root_mean_squared_error: 0.8523 - val_loss: 0.5333 - val_root_mean_squared_error: 0.7303
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.68826
# Epoch 12/70
# 5/5 - 9s - loss: 0.5063 - root_mean_squared_error: 0.7115 - val_loss: 0.4765 - val_root_mean_squared_error: 0.6903
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.68826
# Epoch 13/70
# 5/5 - 9s - loss: 0.7206 - root_mean_squared_error: 0.8489 - val_loss: 0.4065 - val_root_mean_squared_error: 0.6376
#
# Epoch 00013: val_root_mean_squared_error improved from 0.68826 to 0.63756, saving model to Roberta_Base_123_5.h5
# Epoch 14/70
# 5/5 - 9s - loss: 0.6569 - root_mean_squared_error: 0.8105 - val_loss: 0.5184 - val_root_mean_squared_error: 0.7200
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.63756
# Epoch 15/70
# 5/5 - 9s - loss: 0.5123 - root_mean_squared_error: 0.7157 - val_loss: 0.3546 - val_root_mean_squared_error: 0.5955
#
# Epoch 00015: val_root_mean_squared_error improved from 0.63756 to 0.59546, saving model to Roberta_Base_123_5.h5
# Epoch 16/70
# 5/5 - 9s - loss: 0.4239 - root_mean_squared_error: 0.6511 - val_loss: 0.5619 - val_root_mean_squared_error: 0.7496
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.59546
# Epoch 17/70
# 5/5 - 9s - loss: 0.4956 - root_mean_squared_error: 0.7040 - val_loss: 0.3490 - val_root_mean_squared_error: 0.5908
#
# Epoch 00017: val_root_mean_squared_error improved from 0.59546 to 0.59079, saving model to Roberta_Base_123_5.h5
# Epoch 18/70
# 5/5 - 9s - loss: 0.4416 - root_mean_squared_error: 0.6645 - val_loss: 0.4176 - val_root_mean_squared_error: 0.6462
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.59079
# Epoch 19/70
# 5/5 - 9s - loss: 0.3750 - root_mean_squared_error: 0.6124 - val_loss: 0.3447 - val_root_mean_squared_error: 0.5871
#
# Epoch 00019: val_root_mean_squared_error improved from 0.59079 to 0.58711, saving model to Roberta_Base_123_5.h5
# Epoch 20/70
# 5/5 - 9s - loss: 0.3277 - root_mean_squared_error: 0.5725 - val_loss: 0.3488 - val_root_mean_squared_error: 0.5906
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.58711
# Epoch 21/70
# 5/5 - 9s - loss: 0.4550 - root_mean_squared_error: 0.6745 - val_loss: 0.3100 - val_root_mean_squared_error: 0.5568
#
# Epoch 00021: val_root_mean_squared_error improved from 0.58711 to 0.55681, saving model to Roberta_Base_123_5.h5
# Epoch 22/70
# 5/5 - 9s - loss: 0.3121 - root_mean_squared_error: 0.5587 - val_loss: 0.3421 - val_root_mean_squared_error: 0.5849
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.55681
# Epoch 23/70
# 5/5 - 9s - loss: 0.3834 - root_mean_squared_error: 0.6192 - val_loss: 0.3278 - val_root_mean_squared_error: 0.5725
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.55681
# Epoch 24/70
# 5/5 - 9s - loss: 0.3670 - root_mean_squared_error: 0.6058 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5482
#
# Epoch 00024: val_root_mean_squared_error improved from 0.55681 to 0.54824, saving model to Roberta_Base_123_5.h5
# Epoch 25/70
# 5/5 - 9s - loss: 0.2008 - root_mean_squared_error: 0.4481 - val_loss: 0.3109 - val_root_mean_squared_error: 0.5575
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.54824
# Epoch 26/70
# 5/5 - 9s - loss: 0.2191 - root_mean_squared_error: 0.4681 - val_loss: 0.3047 - val_root_mean_squared_error: 0.5520
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.54824
# Epoch 27/70
# 5/5 - 9s - loss: 0.2908 - root_mean_squared_error: 0.5392 - val_loss: 0.3729 - val_root_mean_squared_error: 0.6107
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.54824
# Epoch 28/70
# 5/5 - 9s - loss: 0.3194 - root_mean_squared_error: 0.5652 - val_loss: 0.6777 - val_root_mean_squared_error: 0.8232
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.54824
# Epoch 29/70
# 5/5 - 9s - loss: 0.2506 - root_mean_squared_error: 0.5006 - val_loss: 0.2966 - val_root_mean_squared_error: 0.5446
#
# Epoch 00029: val_root_mean_squared_error improved from 0.54824 to 0.54460, saving model to Roberta_Base_123_5.h5
# Epoch 30/70
# 5/5 - 9s - loss: 0.3054 - root_mean_squared_error: 0.5526 - val_loss: 0.4291 - val_root_mean_squared_error: 0.6550
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.54460
# Epoch 31/70
# 5/5 - 9s - loss: 0.3940 - root_mean_squared_error: 0.6277 - val_loss: 0.5148 - val_root_mean_squared_error: 0.7175
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.54460
# Epoch 32/70
# 5/5 - 9s - loss: 0.4964 - root_mean_squared_error: 0.7046 - val_loss: 0.3485 - val_root_mean_squared_error: 0.5904
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.54460
# Epoch 33/70
# 5/5 - 9s - loss: 0.2846 - root_mean_squared_error: 0.5335 - val_loss: 0.4545 - val_root_mean_squared_error: 0.6742
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.54460
# Epoch 34/70
# 5/5 - 9s - loss: 0.3998 - root_mean_squared_error: 0.6323 - val_loss: 0.4846 - val_root_mean_squared_error: 0.6961
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.54460
# Epoch 35/70
# 5/5 - 9s - loss: 0.4946 - root_mean_squared_error: 0.7033 - val_loss: 0.3000 - val_root_mean_squared_error: 0.5477
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.54460
# Epoch 36/70
# 5/5 - 9s - loss: 0.3091 - root_mean_squared_error: 0.5560 - val_loss: 0.6879 - val_root_mean_squared_error: 0.8294
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.54460
# Epoch 37/70
# 5/5 - 9s - loss: 0.4180 - root_mean_squared_error: 0.6465 - val_loss: 0.2855 - val_root_mean_squared_error: 0.5343
#
# Epoch 00037: val_root_mean_squared_error improved from 0.54460 to 0.53435, saving model to Roberta_Base_123_5.h5
# Epoch 38/70
# 5/5 - 9s - loss: 0.3780 - root_mean_squared_error: 0.6149 - val_loss: 0.2868 - val_root_mean_squared_error: 0.5355
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.53435
# Epoch 39/70
# 5/5 - 9s - loss: 0.3460 - root_mean_squared_error: 0.5882 - val_loss: 0.3283 - val_root_mean_squared_error: 0.5730
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.53435
# Epoch 40/70
# 5/5 - 9s - loss: 0.2844 - root_mean_squared_error: 0.5333 - val_loss: 0.5237 - val_root_mean_squared_error: 0.7237
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.53435
# Epoch 41/70
# 5/5 - 9s - loss: 0.3139 - root_mean_squared_error: 0.5603 - val_loss: 0.2680 - val_root_mean_squared_error: 0.5177
#
# Epoch 00041: val_root_mean_squared_error improved from 0.53435 to 0.51771, saving model to Roberta_Base_123_5.h5
# Epoch 42/70
# 5/5 - 9s - loss: 0.3523 - root_mean_squared_error: 0.5935 - val_loss: 0.3171 - val_root_mean_squared_error: 0.5631
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.51771
# Epoch 43/70
# 5/5 - 9s - loss: 0.2968 - root_mean_squared_error: 0.5448 - val_loss: 0.5922 - val_root_mean_squared_error: 0.7695
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.51771
# Epoch 44/70
# 5/5 - 9s - loss: 0.2382 - root_mean_squared_error: 0.4881 - val_loss: 0.2640 - val_root_mean_squared_error: 0.5138
#
# Epoch 00044: val_root_mean_squared_error improved from 0.51771 to 0.51385, saving model to Roberta_Base_123_5.h5
# Epoch 45/70
# 5/5 - 9s - loss: 0.2797 - root_mean_squared_error: 0.5289 - val_loss: 0.3548 - val_root_mean_squared_error: 0.5956
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.51385
# Epoch 46/70
# 5/5 - 9s - loss: 0.2470 - root_mean_squared_error: 0.4969 - val_loss: 0.3254 - val_root_mean_squared_error: 0.5705
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.51385
# Epoch 47/70
# 5/5 - 9s - loss: 0.2497 - root_mean_squared_error: 0.4997 - val_loss: 0.3021 - val_root_mean_squared_error: 0.5496
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.51385
# Epoch 48/70
# 5/5 - 9s - loss: 0.2624 - root_mean_squared_error: 0.5122 - val_loss: 0.3015 - val_root_mean_squared_error: 0.5491
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.51385
# Epoch 49/70
# 5/5 - 9s - loss: 0.1895 - root_mean_squared_error: 0.4353 - val_loss: 0.3833 - val_root_mean_squared_error: 0.6191
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.51385
# Epoch 50/70
# 5/5 - 9s - loss: 0.1987 - root_mean_squared_error: 0.4457 - val_loss: 0.3207 - val_root_mean_squared_error: 0.5663
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.51385
# Epoch 51/70
# 5/5 - 9s - loss: 0.2629 - root_mean_squared_error: 0.5127 - val_loss: 0.3025 - val_root_mean_squared_error: 0.5500
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.51385
# Epoch 52/70
# 5/5 - 9s - loss: 0.2282 - root_mean_squared_error: 0.4777 - val_loss: 0.4230 - val_root_mean_squared_error: 0.6504
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.51385
# Epoch 53/70
# 5/5 - 9s - loss: 0.2041 - root_mean_squared_error: 0.4518 - val_loss: 0.2970 - val_root_mean_squared_error: 0.5450
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.51385
# Epoch 54/70
# 5/5 - 9s - loss: 0.2429 - root_mean_squared_error: 0.4928 - val_loss: 0.3854 - val_root_mean_squared_error: 0.6208
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.51385
# Epoch 55/70
# 5/5 - 9s - loss: 0.1803 - root_mean_squared_error: 0.4246 - val_loss: 0.5457 - val_root_mean_squared_error: 0.7387
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.51385
# Epoch 56/70
# 5/5 - 9s - loss: 0.1670 - root_mean_squared_error: 0.4087 - val_loss: 0.3012 - val_root_mean_squared_error: 0.5489
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.51385
# Epoch 57/70
# 5/5 - 9s - loss: 0.1743 - root_mean_squared_error: 0.4175 - val_loss: 0.4654 - val_root_mean_squared_error: 0.6822
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.51385
# Epoch 58/70
# 5/5 - 9s - loss: 0.2236 - root_mean_squared_error: 0.4729 - val_loss: 0.4452 - val_root_mean_squared_error: 0.6673
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.51385
# Epoch 59/70
# 5/5 - 9s - loss: 0.2413 - root_mean_squared_error: 0.4912 - val_loss: 0.2626 - val_root_mean_squared_error: 0.5125
#
# Epoch 00059: val_root_mean_squared_error improved from 0.51385 to 0.51246, saving model to Roberta_Base_123_5.h5
# Epoch 60/70
# 5/5 - 9s - loss: 0.1950 - root_mean_squared_error: 0.4416 - val_loss: 0.5378 - val_root_mean_squared_error: 0.7334
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.51246
# Epoch 61/70
# 5/5 - 9s - loss: 0.1637 - root_mean_squared_error: 0.4046 - val_loss: 0.3478 - val_root_mean_squared_error: 0.5897
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.51246
# Epoch 62/70
# 5/5 - 9s - loss: 0.1884 - root_mean_squared_error: 0.4341 - val_loss: 0.2751 - val_root_mean_squared_error: 0.5245
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.51246
# Epoch 63/70
# 5/5 - 9s - loss: 0.1711 - root_mean_squared_error: 0.4137 - val_loss: 0.5937 - val_root_mean_squared_error: 0.7705
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.51246
# Epoch 64/70
# 5/5 - 9s - loss: 0.1839 - root_mean_squared_error: 0.4289 - val_loss: 0.3174 - val_root_mean_squared_error: 0.5634
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.51246
# Epoch 65/70
# 5/5 - 9s - loss: 0.1773 - root_mean_squared_error: 0.4211 - val_loss: 0.2725 - val_root_mean_squared_error: 0.5220
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.51246
# Epoch 66/70
# 5/5 - 9s - loss: 0.1722 - root_mean_squared_error: 0.4149 - val_loss: 0.5272 - val_root_mean_squared_error: 0.7261
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.51246
# Epoch 67/70
# 5/5 - 9s - loss: 0.2061 - root_mean_squared_error: 0.4540 - val_loss: 0.2741 - val_root_mean_squared_error: 0.5235
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.51246
# Epoch 68/70
# 5/5 - 9s - loss: 0.1893 - root_mean_squared_error: 0.4351 - val_loss: 0.3145 - val_root_mean_squared_error: 0.5608
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.51246
# Epoch 69/70
# 5/5 - 9s - loss: 0.1764 - root_mean_squared_error: 0.4200 - val_loss: 0.4320 - val_root_mean_squared_error: 0.6573
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.51246
# Epoch 70/70
# 5/5 - 9s - loss: 0.1662 - root_mean_squared_error: 0.4077 - val_loss: 0.3532 - val_root_mean_squared_error: 0.5943
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.51246
#
#
# --------------------------------------------------
# Our out of folds RMSE is 0.5097949691160628
